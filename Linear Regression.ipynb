# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import mpl_toolkits
import seaborn as sns
# %matplotlib inline

# %%
# Load Dataset — Data Understanding
df_raw = pd.read_csv('Supply_Chain_Shipment_Pricing_Data.csv', delimiter = ',')
df_raw
# Out:
#           id project code            pq #   po / so # asn/dn #        country  \
# 0          1   100-CI-T01  Pre-PQ Process      SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process     SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process     SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process     SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process     SCMS-81   ASN-55        Vietnam
# 5         23   112-NG-T01  Pre-PQ Process     SCMS-87   ASN-57        Nigeria
# 6         44   110-ZM-T01  Pre-PQ Process    SCMS-139  ASN-130         Zambia
# 7         45   109-TZ-T01  Pre-PQ Process    SCMS-140   ASN-94       Tanzania
# 8         46   112-NG-T01  Pre-PQ Process    SCMS-156   ASN-93        Nigeria
# 9         47   110-ZM-T01  Pre-PQ Process    SCMS-165  ASN-199         Zambia
# 10        60   110-ZM-T01  Pre-PQ Process    SCMS-221  ASN-223         Zambia
# 11        61   110-ZM-T01  Pre-PQ Process    SCMS-226  ASN-137         Zambia
# 12        62   102-NG-T01  Pre-PQ Process    SCMS-230  ASN-144        Nigeria
# 13        64   107-RW-T01  Pre-PQ Process    SCMS-268  ASN-242         Rwanda
# 14        65   106-HT-T01  Pre-PQ Process    SCMS-274  ASN-162          Haiti
# 15        68   113-ZW-T01  Pre-PQ Process    SCMS-308  ASN-285       Zimbabwe
# 16        69   102-NG-T01  Pre-PQ Process    SCMS-354  ASN-608        Nigeria
# 17        80   107-RW-T01  Pre-PQ Process    SCMS-488  ASN-299         Rwanda
# 18        87   109-TZ-T01  Pre-PQ Process    SCMS-555  ASN-409       Tanzania
# 19        92   102-NG-T01  Pre-PQ Process    SCMS-592  ASN-485        Nigeria
# 20        96   102-NG-T01  Pre-PQ Process    SCMS-570  ASN-451        Nigeria
# 21       108   104-CI-T01  Pre-PQ Process    SCMS-698  ASN-727  Côte d'Ivoire
# 22       115   108-VN-T01  Pre-PQ Process    SCMS-753  ASN-781        Vietnam
# 23       116   108-VN-T01  Pre-PQ Process    SCMS-759  ASN-632        Vietnam
# 24       130   100-HT-T01  Pre-PQ Process  SCMS-10080  ASN-628          Haiti
# 25       134   100-HT-T01  Pre-PQ Process  SCMS-10130  ASN-616          Haiti
# 26       138   109-TZ-T01  Pre-PQ Process  SCMS-10270  ASN-710       Tanzania
# 27       139   109-TZ-T01  Pre-PQ Process  SCMS-10290  ASN-788       Tanzania
# 28       140   109-TZ-T01  Pre-PQ Process  SCMS-10300  ASN-856       Tanzania
# 29       161   117-ET-T01  Pre-PQ Process  SCMS-11070  ASN-916       Ethiopia
# ...      ...          ...             ...         ...      ...            ...
# 10294  86788   102-BI-T30       FPQ-15406    SO-50280  DN-4178        Burundi
# 10295  86789   102-BI-T30       FPQ-15406    SO-50280  DN-4178        Burundi
# 10296  86790   151-NG-T30       FPQ-14989    SO-49931  DN-4187        Nigeria
# 10297  86791   101-CD-T30       FPQ-15787    SO-50910  DN-4195     Congo, DRC
# 10298  86795   102-BI-T30       FPQ-15406    SO-50290  DN-4210        Burundi
# 10299  86796   104-CI-T30       FPQ-15259    SO-50101  DN-4211  Côte d'Ivoire
# 10300  86797   114-UG-T30       FPQ-15639    SO-50670  DN-4215         Uganda
# 10301  86798   114-UG-T30       FPQ-15294    SO-50050  DN-4218         Uganda
# 10302  86799   103-ZW-T30       FPQ-15197    SO-50011  DN-4225       Zimbabwe
# 10303  86800   111-MZ-T30       FPQ-15195    SO-50141  DN-4231     Mozambique
# 10304  86801   111-MZ-T30       FPQ-13575    SO-47707  DN-4234     Mozambique
# 10305  86802   111-MZ-T30       FPQ-15195    SO-50130  DN-4235     Mozambique
# 10306  86803   111-MZ-T30       FPQ-14843    SO-49721  DN-4236     Mozambique
# 10307  86805   103-ZW-T30       FPQ-15197    SO-50010  DN-4243       Zimbabwe
# 10308  86806   110-ZM-T30       FPQ-14784    SO-49601  DN-4250         Zambia
# 10309  86807   110-ZM-T30       FPQ-14784    SO-49601  DN-4250         Zambia
# 10310  86808   114-UG-T30       FPQ-15294    SO-50070  DN-4259         Uganda
# 10311  86809   114-UG-T30       FPQ-15294    SO-50070  DN-4259         Uganda
# 10312  86810   114-UG-T30       FPQ-15294    SO-50054  DN-4265         Uganda
# 10313  86812   104-CI-T30       FPQ-14370    SO-49090  DN-4177  Côte d'Ivoire
# 10314  86813   151-NG-T30       FPQ-14989    SO-51422  DN-4274        Nigeria
# 10315  86814   151-NG-T30       FPQ-14989    SO-51424  DN-4276        Nigeria
# 10316  86815   151-NG-T30       FPQ-16313    SO-51420  DN-4279        Nigeria
# 10317  86816   151-NG-T30       FPQ-16313    SO-51440  DN-4282        Nigeria
# 10318  86817   103-ZW-T30       FPQ-15197    SO-50020  DN-4307       Zimbabwe
# 10319  86818   103-ZW-T30       FPQ-15197    SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259    SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784    SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523    SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197    SO-50022  DN-4336       Zimbabwe
#
#       managed by  fulfill via vendor inco term shipment mode  \
# 0       PMO - US  Direct Drop              EXW           Air
# 1       PMO - US  Direct Drop              EXW           Air
# 2       PMO - US  Direct Drop              FCA           Air
# 3       PMO - US  Direct Drop              EXW           Air
# 4       PMO - US  Direct Drop              EXW           Air
# 5       PMO - US  Direct Drop              EXW           Air
# 6       PMO - US  Direct Drop              DDU           Air
# 7       PMO - US  Direct Drop              EXW           Air
# 8       PMO - US  Direct Drop              EXW           Air
# 9       PMO - US  Direct Drop              CIP           Air
# 10      PMO - US  Direct Drop              CIP           Air
# 11      PMO - US  Direct Drop              EXW           Air
# 12      PMO - US  Direct Drop              EXW           Air
# 13      PMO - US  Direct Drop              EXW           Air
# 14      PMO - US  Direct Drop              EXW           Air
# 15      PMO - US  Direct Drop              CIP           Air
# 16      PMO - US  Direct Drop              CIP           NaN
# 17      PMO - US  Direct Drop              EXW           Air
# 18      PMO - US  Direct Drop              CIP           Air
# 19      PMO - US  Direct Drop              EXW           Air
# 20      PMO - US  Direct Drop              EXW           Air
# 21      PMO - US  Direct Drop              CIP           Air
# 22      PMO - US  Direct Drop              EXW           Air
# 23      PMO - US  Direct Drop              FCA           Air
# 24      PMO - US  Direct Drop              EXW           Air
# 25      PMO - US  Direct Drop              EXW           Air
# 26      PMO - US  Direct Drop              EXW           Air
# 27      PMO - US  Direct Drop              EXW           Air
# 28      PMO - US  Direct Drop              EXW           Air
# 29      PMO - US  Direct Drop              EXW           Air
# ...          ...          ...              ...           ...
# 10294   PMO - US     From RDC   N/A - From RDC           Air
# 10295   PMO - US     From RDC   N/A - From RDC           Air
# 10296   PMO - US     From RDC   N/A - From RDC   Air Charter
# 10297   PMO - US     From RDC   N/A - From RDC           Air
# 10298   PMO - US     From RDC   N/A - From RDC           Air
# 10299   PMO - US     From RDC   N/A - From RDC         Truck
# 10300   PMO - US     From RDC   N/A - From RDC         Truck
# 10301   PMO - US     From RDC   N/A - From RDC         Truck
# 10302   PMO - US     From RDC   N/A - From RDC         Truck
# 10303   PMO - US     From RDC   N/A - From RDC         Truck
# 10304   PMO - US     From RDC   N/A - From RDC         Truck
# 10305   PMO - US     From RDC   N/A - From RDC         Truck
# 10306   PMO - US     From RDC   N/A - From RDC         Truck
# 10307   PMO - US     From RDC   N/A - From RDC         Truck
# 10308   PMO - US     From RDC   N/A - From RDC         Truck
# 10309   PMO - US     From RDC   N/A - From RDC         Truck
# 10310   PMO - US     From RDC   N/A - From RDC         Truck
# 10311   PMO - US     From RDC   N/A - From RDC         Truck
# 10312   PMO - US     From RDC   N/A - From RDC         Truck
# 10313   PMO - US     From RDC   N/A - From RDC         Truck
# 10314   PMO - US     From RDC   N/A - From RDC   Air Charter
# 10315   PMO - US     From RDC   N/A - From RDC   Air Charter
# 10316   PMO - US     From RDC   N/A - From RDC   Air Charter
# 10317   PMO - US     From RDC   N/A - From RDC           Air
# 10318   PMO - US     From RDC   N/A - From RDC         Truck
# 10319   PMO - US     From RDC   N/A - From RDC         Truck
# 10320   PMO - US     From RDC   N/A - From RDC         Truck
# 10321   PMO - US     From RDC   N/A - From RDC         Truck
# 10322   PMO - US     From RDC   N/A - From RDC         Truck
# 10323   PMO - US     From RDC   N/A - From RDC         Truck
#
#                  ...            unit of measure (per pack) line item quantity  \
# 0                ...                                    30                 19
# 1                ...                                   240               1000
# 2                ...                                   100                500
# 3                ...                                    60              31920
# 4                ...                                    60              38000
# 5                ...                                   240                416
# 6                ...                                    90                135
# 7                ...                                    60              16667
# 8                ...                                    60                273
# 9                ...                                   120               2800
# 10               ...                                   120               2800
# 11               ...                                    20               2500
# 12               ...                                   100                 10
# 13               ...                                    60              10000
# 14               ...                                   100                750
# 15               ...                                    60                579
# 16               ...                                   100               1500
# 17               ...                                    30               2000
# 18               ...                                   200                712
# 19               ...                                   100               1000
# 20               ...                                    20               7500
# 21               ...                                    60               5513
# 22               ...                                   240               1000
# 23               ...                                   120                500
# 24               ...                                   100                750
# 25               ...                                   100                 25
# 26               ...                                    25              10000
# 27               ...                                    25              10000
# 28               ...                                    25              10000
# 29               ...                                    60              64000
# ...              ...                                   ...                ...
# 10294            ...                                    60               1008
# 10295            ...                                    60                282
# 10296            ...                                   120              13130
# 10297            ...                                    60                490
# 10298            ...                                    60               1056
# 10299            ...                                    30               8250
# 10300            ...                                    60              21667
# 10301            ...                                    30              29998
# 10302            ...                                    60              47733
# 10303            ...                                    30             200000
# 10304            ...                                    60              28516
# 10305            ...                                    60             300000
# 10306            ...                                    30              16006
# 10307            ...                                    60              46752
# 10308            ...                                    90              15000
# 10309            ...                                    60               2016
# 10310            ...                                    60              18000
# 10311            ...                                    60              29287
# 10312            ...                                    90               6312
# 10313            ...                                    30              19996
# 10314            ...                                    60              10340
# 10315            ...                                   120              70000
# 10316            ...                                    60              15000
# 10317            ...                                    30               6724
# 10318            ...                                    60             205243
# 10319            ...                                    60             166571
# 10320            ...                                    60              21072
# 10321            ...                                    30             514526
# 10322            ...                                    60              17465
# 10323            ...                                    60              36639
#
#       line item value pack price unit price              manufacturing site  \
# 0              551.00      29.00       0.97      Ranbaxy Fine Chemicals LTD
# 1             6200.00       6.20       0.03       Aurobindo Unit III, India
# 2            40000.00      80.00       0.80   ABBVIE GmbH & Co.KG Wiesbaden
# 3           127360.80       3.99       0.07   Ranbaxy, Paonta Shahib, India
# 4           121600.00       3.20       0.05       Aurobindo Unit III, India
# 5             2225.60       5.35       0.02       Aurobindo Unit III, India
# 6             4374.00      32.40       0.36   MSD South Granville Australia
# 7            60834.55       3.65       0.06       Aurobindo Unit III, India
# 8              532.35       1.95       0.03       Aurobindo Unit III, India
# 9           115080.00      41.10       0.34  ABBVIE (Abbott) St. P'burg USA
# 10          115080.00      41.10       0.34     ABBVIE Ludwigshafen Germany
# 11          100000.00      40.00       2.00            Trinity Biotech, Plc
# 12             850.00      85.00       0.85            EY Laboratories, USA
# 13           99800.00       9.98       0.17               Cipla, Goa, India
# 14           60000.00      80.00       0.80   ABBVIE GmbH & Co.KG Wiesbaden
# 15           14764.50      25.50       0.42              BMS Meymac, France
# 16          120000.00      80.00       0.80   ABBVIE GmbH & Co.KG Wiesbaden
# 17           33000.00      16.50       0.55    Premier Med. Corp Ltd. India
# 18            8964.08      12.59       0.06              BMS Meymac, France
# 19           80000.00      80.00       0.80   ABBVIE GmbH & Co.KG Wiesbaden
# 20          202500.00      27.00       1.35   Chembio Diagnostics Sys. Inc.
# 21          140581.50      25.50       0.42              BMS Meymac, France
# 22            1920.00       1.92       0.01       Aurobindo Unit III, India
# 23           41095.00      82.19       0.68     ABBVIE Ludwigshafen Germany
# 24           53992.50      71.99       0.72                 Inverness Japan
# 25            8750.00     350.00       3.50       Pacific Biotech, Thailand
# 26          200000.00      20.00       0.80     Standard Diagnostics, Korea
# 27          200000.00      20.00       0.80     Standard Diagnostics, Korea
# 28          200000.00      20.00       0.80     Standard Diagnostics, Korea
# 29           99200.00       1.55       0.03       Aurobindo Unit III, India
# ...               ...        ...        ...                             ...
# 10294         7781.76       7.72       0.13   Hetero, Jadcherla, unit 5, IN
# 10295          549.90       1.95       0.03      Mylan,  H-12 & H-13, India
# 10296       244743.20      18.64       0.16     ABBVIE Ludwigshafen Germany
# 10297          955.50       1.95       0.03      Mylan,  H-12 & H-13, India
# 10298         8152.32       7.72       0.13  Mylan (formerly Matrix) Nashik
# 10299        37867.50       4.59       0.15          Cipla, Kurkumbh, India
# 10300       167269.24       7.72       0.13  Mylan (formerly Matrix) Nashik
# 10301        93593.76       3.12       0.10    Hetero Unit III Hyderabad IN
# 10302        91647.36       1.92       0.03               Cipla, Goa, India
# 10303      1920000.00       9.60       0.32    Hetero Unit III Hyderabad IN
# 10304       220143.52       7.72       0.13    Hetero Unit III Hyderabad IN
# 10305      2316000.00       7.72       0.13    Hetero Unit III Hyderabad IN
# 10306        73467.54       4.59       0.15   Hetero, Jadcherla, unit 5, IN
# 10307       168307.20       3.60       0.06               Cipla, Goa, India
# 10308        82500.00       5.50       0.06      Strides, Bangalore, India.
# 10309         5019.84       2.49       0.04    Hetero Unit III Hyderabad IN
# 10310        64800.00       3.60       0.06  Mylan (formerly Matrix) Nashik
# 10311       105433.20       3.60       0.06      Strides, Bangalore, India.
# 10312        34716.00       5.50       0.06      Strides, Bangalore, India.
# 10313        62387.52       3.12       0.10   Micro labs, Verna, Goa, India
# 10314        37224.00       3.60       0.06  Mylan (formerly Matrix) Nashik
# 10315      1304800.00      18.64       0.16     ABBVIE Ludwigshafen Germany
# 10316        97800.00       6.52       0.11       Aurobindo Unit III, India
# 10317        20978.88       3.12       0.10      Strides, Bangalore, India.
# 10318       738874.80       3.60       0.06               Cipla, Goa, India
# 10319       599655.60       3.60       0.06      Mylan,  H-12 & H-13, India
# 10320       137389.44       6.52       0.11    Hetero Unit III Hyderabad IN
# 10321      5140114.74       9.99       0.33   Cipla Ltd A-42 MIDC Mahar. IN
# 10322       113871.80       6.52       0.11  Mylan (formerly Matrix) Nashik
# 10323        72911.61       1.99       0.03               Cipla, Goa, India
#
#       first line designation          weight (kilograms)  \
# 0                       True                          13
# 1                       True                         358
# 2                       True                         171
# 3                       True                        1855
# 4                       True                        7590
# 5                       True                         504
# 6                       True                         328
# 7                       True                        1478
# 8                      False       See ASN-93 (ID#:1281)
# 9                       True                         643
# 10                      True                         643
# 11                      True                         853
# 12                      True  Weight Captured Separately
# 13                      True                        7416
# 14                      True                         256
# 15                      True  Weight Captured Separately
# 16                      True  Weight Captured Separately
# 17                      True                         710
# 18                      True                         162
# 19                      True                         341
# 20                      True                        2278
# 21                      True                        2126
# 22                      True                         941
# 23                      True                         117
# 24                      True                         171
# 25                      True                          60
# 26                      True                        3335
# 27                      True                        3335
# 28                      True                        3335
# 29                      True                        4228
# ...                      ...                         ...
# 10294                  False     See DN-4178 (ID#:84460)
# 10295                  False     See DN-4178 (ID#:84460)
# 10296                   True                        3232
# 10297                  False     See DN-4195 (ID#:83324)
# 10298                  False     See DN-4210 (ID#:83906)
# 10299                   True                         821
# 10300                  False  Weight Captured Separately
# 10301                  False     See DN-4218 (ID#:83326)
# 10302                   True                        6368
# 10303                   True                       26603
# 10304                   True                        3772
# 10305                   True                       39688
# 10306                   True                        1504
# 10307                  False     See DN-4243 (ID#:83907)
# 10308                  False     See DN-4250 (ID#:82799)
# 10309                  False     See DN-4250 (ID#:82799)
# 10310                   True                        2253
# 10311                  False     See DN-4259 (ID#:86808)
# 10312                  False     See DN-4265 (ID#:83335)
# 10313                  False     See DN-4177 (ID#:82804)
# 10314                  False     See DN-4274 (ID#:84472)
# 10315                   True                       15198
# 10316                   True                        1547
# 10317                  False     See DN-4282 (ID#:83919)
# 10318                  False     See DN-4307 (ID#:83920)
# 10319                  False     See DN-4307 (ID#:83920)
# 10320                  False     See DN-4313 (ID#:83921)
# 10321                  False  Weight Captured Separately
# 10322                   True                        1392
# 10323                  False  Weight Captured Separately
#
#                        freight cost (usd) line item insurance (usd)
# 0                                  780.34                       NaN
# 1                                  4521.5                       NaN
# 2                                 1653.78                       NaN
# 3                                16007.06                       NaN
# 4                                45450.08                       NaN
# 5                                 5920.42                       NaN
# 6      Freight Included in Commodity Cost                       NaN
# 7                                 6212.41                       NaN
# 8                   See ASN-93 (ID#:1281)                       NaN
# 9      Freight Included in Commodity Cost                       NaN
# 10     Freight Included in Commodity Cost                       NaN
# 11                               13569.49                       NaN
# 12                    Invoiced Separately                       NaN
# 13                               64179.42                       NaN
# 14                                1760.32                       NaN
# 15     Freight Included in Commodity Cost                       NaN
# 16     Freight Included in Commodity Cost                    192.00
# 17                                 3120.7                       NaN
# 18                                 912.96                       NaN
# 19                                2682.47                    128.00
# 20                               15893.71                       NaN
# 21     Freight Included in Commodity Cost                    224.93
# 22                                4193.49                      3.07
# 23                                1767.38                     65.75
# 24                                3518.38                     86.39
# 25                                3097.85                     14.00
# 26                               27869.74                    320.00
# 27                                28461.1                    320.00
# 28                                28359.8                    320.00
# 29                               12237.61                    158.72
# ...                                   ...                       ...
# 10294             See DN-4178 (ID#:84460)                      9.16
# 10295             See DN-4178 (ID#:84460)                      0.65
# 10296                             4495.29                    251.60
# 10297             See DN-4195 (ID#:83324)                      1.12
# 10298             See DN-4210 (ID#:83906)                      9.60
# 10299                              6695.9                     44.57
# 10300  Freight Included in Commodity Cost                    196.88
# 10301             See DN-4218 (ID#:83326)                    110.16
# 10302                             2592.56                    107.87
# 10303                            19194.37                   2259.84
# 10304                             3567.08                    226.31
# 10305                            28277.42                   2725.93
# 10306                              1653.9                     75.52
# 10307             See DN-4243 (ID#:83907)                    198.10
# 10308             See DN-4250 (ID#:82799)                     84.81
# 10309             See DN-4250 (ID#:82799)                      5.16
# 10310                             3785.72                     76.27
# 10311             See DN-4259 (ID#:86808)                    124.09
# 10312             See DN-4265 (ID#:83335)                     40.86
# 10313             See DN-4177 (ID#:82804)                     64.13
# 10314             See DN-4274 (ID#:84472)                     38.27
# 10315                               26180                   1341.33
# 10316                                3410                    115.11
# 10317             See DN-4282 (ID#:83919)                     24.69
# 10318             See DN-4307 (ID#:83920)                    869.66
# 10319             See DN-4307 (ID#:83920)                    705.79
# 10320             See DN-4313 (ID#:83921)                    161.71
# 10321  Freight Included in Commodity Cost                   5284.04
# 10322  Freight Included in Commodity Cost                    134.03
# 10323  Freight Included in Commodity Cost                     85.82
#
# [10324 rows x 33 columns]

# %%
df = df_raw[['country','fulfill via','vendor inco term','shipment mode','product group','sub classification','brand','unit of measure (per pack)','line item quantity','line item value','pack price','unit price','weight (kilograms)', 'freight cost (usd)', 'line item insurance (usd)']]
df.head(10)
# Out:
#          country  fulfill via vendor inco term shipment mode product group  \
# 0  Côte d'Ivoire  Direct Drop              EXW           Air          HRDT
# 1        Vietnam  Direct Drop              EXW           Air           ARV
# 2  Côte d'Ivoire  Direct Drop              FCA           Air          HRDT
# 3        Vietnam  Direct Drop              EXW           Air           ARV
# 4        Vietnam  Direct Drop              EXW           Air           ARV
# 5        Nigeria  Direct Drop              EXW           Air           ARV
# 6         Zambia  Direct Drop              DDU           Air           ARV
# 7       Tanzania  Direct Drop              EXW           Air           ARV
# 8        Nigeria  Direct Drop              EXW           Air           ARV
# 9         Zambia  Direct Drop              CIP           Air           ARV
#
#   sub classification            brand  unit of measure (per pack)  \
# 0           HIV test           Reveal                          30
# 1          Pediatric          Generic                         240
# 2           HIV test        Determine                         100
# 3              Adult          Generic                          60
# 4              Adult          Generic                          60
# 5          Pediatric          Generic                         240
# 6          Pediatric  Stocrin/Sustiva                          90
# 7              Adult          Generic                          60
# 8              Adult          Generic                          60
# 9              Adult           Aluvia                         120
#
#    line item quantity  line item value  pack price  unit price  \
# 0                  19           551.00       29.00        0.97
# 1                1000          6200.00        6.20        0.03
# 2                 500         40000.00       80.00        0.80
# 3               31920        127360.80        3.99        0.07
# 4               38000        121600.00        3.20        0.05
# 5                 416          2225.60        5.35        0.02
# 6                 135          4374.00       32.40        0.36
# 7               16667         60834.55        3.65        0.06
# 8                 273           532.35        1.95        0.03
# 9                2800        115080.00       41.10        0.34
#
#       weight (kilograms)                  freight cost (usd)  \
# 0                     13                              780.34
# 1                    358                              4521.5
# 2                    171                             1653.78
# 3                   1855                            16007.06
# 4                   7590                            45450.08
# 5                    504                             5920.42
# 6                    328  Freight Included in Commodity Cost
# 7                   1478                             6212.41
# 8  See ASN-93 (ID#:1281)               See ASN-93 (ID#:1281)
# 9                    643  Freight Included in Commodity Cost
#
#    line item insurance (usd)
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 15 columns):
# country                       10324 non-null object
# fulfill via                   10324 non-null object
# vendor inco term              10324 non-null object
# shipment mode                 9964 non-null object
# product group                 10324 non-null object
# sub classification            10324 non-null object
# brand                         10324 non-null object
# unit of measure (per pack)    10324 non-null int64
# line item quantity            10324 non-null int64
# line item value               10324 non-null float64
# pack price                    10324 non-null float64
# unit price                    10324 non-null float64
# weight (kilograms)            10324 non-null object
# freight cost (usd)            10324 non-null object
# line item insurance (usd)     10037 non-null float64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
df['freight cost (usd)'] = pd.to_numeric(df['freight cost (usd)'], errors='coerce')
df['weight (kilograms)'] = pd.to_numeric(df['weight (kilograms)'], errors='coerce')
# Out:
# C:\Users\housh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\housh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 15 columns):
# country                       10324 non-null object
# fulfill via                   10324 non-null object
# vendor inco term              10324 non-null object
# shipment mode                 9964 non-null object
# product group                 10324 non-null object
# sub classification            10324 non-null object
# brand                         10324 non-null object
# unit of measure (per pack)    10324 non-null int64
# line item quantity            10324 non-null int64
# line item value               10324 non-null float64
# pack price                    10324 non-null float64
# unit price                    10324 non-null float64
# weight (kilograms)            6372 non-null float64
# freight cost (usd)            6198 non-null float64
# line item insurance (usd)     10037 non-null float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
# Descriptive Stats — Data Understanding
df.isnull().mean().sort_values(ascending=False)*100
# Out:
# freight cost (usd)            39.965130
# weight (kilograms)            38.279737
# shipment mode                  3.487021
# line item insurance (usd)      2.779930
# unit price                     0.000000
# pack price                     0.000000
# line item value                0.000000
# line item quantity             0.000000
# unit of measure (per pack)     0.000000
# brand                          0.000000
# sub classification             0.000000
# product group                  0.000000
# vendor inco term               0.000000
# fulfill via                    0.000000
# country                        0.000000
# dtype: float64

# %%
df = df[np.isfinite(df['freight cost (usd)'])]
df = df[np.isfinite(df['line item insurance (usd)'])]
df = df[np.isfinite(df['weight (kilograms)'])]
df = df.dropna(axis=0, subset=['shipment mode'])
df
# Out:
#              country  fulfill via vendor inco term shipment mode  \
# 19           Nigeria  Direct Drop              EXW           Air
# 22           Vietnam  Direct Drop              EXW           Air
# 23           Vietnam  Direct Drop              FCA           Air
# 24             Haiti  Direct Drop              EXW           Air
# 25             Haiti  Direct Drop              EXW           Air
# 26          Tanzania  Direct Drop              EXW           Air
# 27          Tanzania  Direct Drop              EXW           Air
# 28          Tanzania  Direct Drop              EXW           Air
# 29          Ethiopia  Direct Drop              EXW           Air
# 30           Nigeria  Direct Drop              EXW           Air
# 32           Vietnam  Direct Drop              EXW           Air
# 33           Vietnam  Direct Drop              EXW           Air
# 34            Rwanda  Direct Drop              EXW           Air
# 38     Côte d'Ivoire  Direct Drop              EXW           Air
# 39     Côte d'Ivoire  Direct Drop              EXW           Air
# 41            Guyana  Direct Drop              EXW           Air
# 43          Zimbabwe  Direct Drop              EXW           Air
# 44           Nigeria  Direct Drop              EXW           Air
# 45           Namibia  Direct Drop              EXW           Air
# 46           Vietnam  Direct Drop              EXW           Air
# 49           Vietnam  Direct Drop              CIP           Air
# 51           Nigeria  Direct Drop              EXW           Air
# 54           Vietnam  Direct Drop              EXW           Air
# 58          Tanzania  Direct Drop              CIP           Air
# 59             Haiti  Direct Drop              EXW           Air
# 60             Haiti  Direct Drop              EXW           Air
# 62           Vietnam  Direct Drop              EXW           Air
# 63           Nigeria  Direct Drop              EXW           Air
# 64           Vietnam  Direct Drop              EXW           Air
# 66           Vietnam  Direct Drop              EXW           Air
# ...              ...          ...              ...           ...
# 10247         Uganda     From RDC   N/A - From RDC         Truck
# 10248         Guyana     From RDC   N/A - From RDC           Air
# 10253       Zimbabwe     From RDC   N/A - From RDC           Air
# 10256         Uganda     From RDC   N/A - From RDC         Truck
# 10257         Rwanda     From RDC   N/A - From RDC         Truck
# 10258        Nigeria     From RDC   N/A - From RDC   Air Charter
# 10260       Zimbabwe     From RDC   N/A - From RDC         Truck
# 10261         Zambia     From RDC   N/A - From RDC         Truck
# 10267        Nigeria     From RDC   N/A - From RDC   Air Charter
# 10268        Nigeria     From RDC   N/A - From RDC   Air Charter
# 10269     Mozambique     From RDC   N/A - From RDC         Truck
# 10270         Guyana     From RDC   N/A - From RDC           Air
# 10274  Côte d'Ivoire     From RDC   N/A - From RDC         Truck
# 10278        Nigeria     From RDC   N/A - From RDC   Air Charter
# 10281  Côte d'Ivoire     From RDC   N/A - From RDC         Truck
# 10282         Zambia     From RDC   N/A - From RDC         Truck
# 10286         Uganda     From RDC   N/A - From RDC         Truck
# 10287     Congo, DRC     From RDC   N/A - From RDC           Air
# 10292         Uganda     From RDC   N/A - From RDC         Truck
# 10293         Rwanda     From RDC   N/A - From RDC           Air
# 10296        Nigeria     From RDC   N/A - From RDC   Air Charter
# 10299  Côte d'Ivoire     From RDC   N/A - From RDC         Truck
# 10302       Zimbabwe     From RDC   N/A - From RDC         Truck
# 10303     Mozambique     From RDC   N/A - From RDC         Truck
# 10304     Mozambique     From RDC   N/A - From RDC         Truck
# 10305     Mozambique     From RDC   N/A - From RDC         Truck
# 10306     Mozambique     From RDC   N/A - From RDC         Truck
# 10310         Uganda     From RDC   N/A - From RDC         Truck
# 10315        Nigeria     From RDC   N/A - From RDC   Air Charter
# 10316        Nigeria     From RDC   N/A - From RDC   Air Charter
#
#       product group    sub classification      brand  \
# 19             HRDT              HIV test  Determine
# 22              ARV             Pediatric    Generic
# 23              ARV                 Adult     Aluvia
# 24             HRDT              HIV test  Determine
# 25             HRDT              HIV test   OraQuick
# 26             HRDT              HIV test    Bioline
# 27             HRDT              HIV test    Bioline
# 28             HRDT              HIV test    Bioline
# 29              ARV                 Adult    Generic
# 30             HRDT              HIV test   Stat-Pak
# 32              ARV                 Adult     Viread
# 33              ARV                 Adult    Generic
# 34             HRDT  HIV test - Ancillary    Generic
# 38             HRDT              HIV test      Genie
# 39             HRDT              HIV test    Bioline
# 41             HRDT  HIV test - Ancillary    Generic
# 43             HRDT              HIV test  Determine
# 44             HRDT              HIV test   Stat-Pak
# 45             HRDT              HIV test  Determine
# 46              ARV                 Adult    Generic
# 49              ARV             Pediatric      Videx
# 51             HRDT              HIV test  Determine
# 54              ARV                 Adult    Generic
# 58              ARV                 Adult   Videx EC
# 59             HRDT              HIV test   OraQuick
# 60             HRDT              HIV test   Capillus
# 62              ARV                 Adult    Generic
# 63              ACT                   ACT    Coartem
# 64              ARV                 Adult    Generic
# 66              ARV                 Adult    Generic
# ...             ...                   ...        ...
# 10247           ARV                 Adult    Generic
# 10248           ARV             Pediatric    Generic
# 10253           ARV             Pediatric    Generic
# 10256           ARV                 Adult     Aluvia
# 10257           ARV                 Adult    Generic
# 10258           ARV             Pediatric    Generic
# 10260           ARV             Pediatric    Generic
# 10261           ARV                 Adult    Generic
# 10267           ARV             Pediatric    Generic
# 10268           ARV                 Adult    Generic
# 10269           ARV                 Adult    Generic
# 10270           ARV                 Adult    Generic
# 10274           ARV                 Adult    Generic
# 10278           ARV                 Adult    Generic
# 10281           ARV                 Adult    Generic
# 10282           ARV                 Adult    Generic
# 10286           ARV             Pediatric    Generic
# 10287           ARV                 Adult    Generic
# 10292           ARV                 Adult    Generic
# 10293           ARV                 Adult    Generic
# 10296           ARV                 Adult     Aluvia
# 10299           ARV                 Adult    Generic
# 10302           ARV             Pediatric    Generic
# 10303           ARV                 Adult    Generic
# 10304           ARV                 Adult    Generic
# 10305           ARV                 Adult    Generic
# 10306           ARV                 Adult    Generic
# 10310           ARV             Pediatric    Generic
# 10315           ARV                 Adult     Aluvia
# 10316           ARV                 Adult    Generic
#
#        unit of measure (per pack)  line item quantity  line item value  \
# 19                            100                1000         80000.00
# 22                            240                1000          1920.00
# 23                            120                 500         41095.00
# 24                            100                 750         53992.50
# 25                            100                  25          8750.00
# 26                             25               10000        200000.00
# 27                             25               10000        200000.00
# 28                             25               10000        200000.00
# 29                             60               64000         99200.00
# 30                             20               10000        270000.00
# 32                             30                1000         17000.00
# 33                             60                 400          3352.00
# 34                            100                1500            15.00
# 38                             40                 476         36176.00
# 39                             25                 659         13180.00
# 41                            100                 213             2.13
# 43                            100                1634        117631.66
# 44                             20                1425         38475.00
# 45                            100                 142         10222.58
# 46                             30                8400         96432.00
# 49                             60                 400          2800.00
# 51                            100                5498        439785.02
# 54                             30                1344         18359.04
# 58                             30                2597         61470.99
# 59                            100                  28          9800.00
# 60                            100                  84         11676.00
# 62                             60               38640         92736.00
# 63                            540                  34          1547.68
# 64                             60               42000         60900.00
# 66                             30               16800        171192.00
# ...                           ...                 ...              ...
# 10247                          60               45950        372654.50
# 10248                          90                  75           697.50
# 10253                          60                1973          7892.00
# 10256                         120                5337        100869.30
# 10257                          60               86008        697524.88
# 10258                          60               65761        245288.53
# 10260                          60               66023        246265.79
# 10261                          60               14653         96709.80
# 10267                          90                 635          5905.50
# 10268                          30               12241         39293.61
# 10269                          30                3793         51281.36
# 10270                          60                 228          1504.80
# 10274                          30                2400         32376.00
# 10278                          30               57000        263340.00
# 10281                          60               55995        365087.40
# 10282                          30               18447         85225.14
# 10286                          60                5000         18650.00
# 10287                          30               55300        539728.00
# 10292                          30               27365        125605.35
# 10293                          30                 200           710.00
# 10296                         120               13130        244743.20
# 10299                          30                8250         37867.50
# 10302                          60               47733         91647.36
# 10303                          30              200000       1920000.00
# 10304                          60               28516        220143.52
# 10305                          60              300000       2316000.00
# 10306                          30               16006         73467.54
# 10310                          60               18000         64800.00
# 10315                         120               70000       1304800.00
# 10316                          60               15000         97800.00
#
#        pack price  unit price  weight (kilograms)  freight cost (usd)  \
# 19          80.00        0.80               341.0             2682.47
# 22           1.92        0.01               941.0             4193.49
# 23          82.19        0.68               117.0             1767.38
# 24          71.99        0.72               171.0             3518.38
# 25         350.00        3.50                60.0             3097.85
# 26          20.00        0.80              3335.0            27869.74
# 27          20.00        0.80              3335.0            28461.10
# 28          20.00        0.80              3335.0            28359.80
# 29           1.55        0.03              4228.0            12237.61
# 30          27.00        1.35              3263.0            20885.78
# 32          17.00        0.57                76.0             2282.57
# 33           8.38        0.14                23.0             2149.05
# 34           0.01        0.00                99.0                0.75
# 38          76.00        1.90               509.0             5446.51
# 39          20.00        0.80               206.0             2656.12
# 41           0.01        0.00                14.0              360.00
# 43          71.99        0.72               373.0             4112.46
# 44          27.00        1.35               483.0             5468.88
# 45          71.99        0.72                33.0             1715.17
# 46          11.48        0.38               654.0             4051.34
# 49           7.00        0.12                81.0             2211.05
# 51          79.99        0.80              1251.0            16090.22
# 54          13.66        0.46              1537.0            13507.92
# 58          23.67        0.79               117.0              645.10
# 59         350.00        3.50               109.0              782.13
# 60         139.00        1.39                54.0              871.57
# 62           2.40        0.04              2719.0            18614.72
# 63          45.52        0.08               115.0             1755.87
# 64           1.45        0.02              2600.0            10179.16
# 66          10.19        0.34              1224.0             4686.88
# ...           ...         ...                 ...                 ...
# 10247        8.11        0.14              6061.0             6901.96
# 10248        9.30        0.10                 5.0              908.65
# 10253        4.00        0.07              8894.0              102.67
# 10256       18.90        0.16              1089.0             3730.80
# 10257        8.11        0.14             11117.0            15617.93
# 10258        3.73        0.06              3156.0            28812.57
# 10260        3.73        0.06              5780.0            15789.20
# 10261        6.60        0.11              1413.0             1325.68
# 10267        9.30        0.10                65.0              177.00
# 10268        3.21        0.11               828.0             3773.00
# 10269       13.52        0.45               383.0              123.70
# 10270        6.60        0.11                21.0              973.48
# 10274       13.49        0.45               213.0             1422.54
# 10278        4.62        0.15              5735.0            20138.00
# 10281        6.52        0.11              4899.0            19497.24
# 10282        4.62        0.15              1906.0             2201.74
# 10286        3.73        0.06               297.0             1326.00
# 10287        9.76        0.33              6247.0            61201.46
# 10292        4.59        0.15              2885.0             2564.94
# 10293        3.55        0.12                12.0             1301.94
# 10296       18.64        0.16              3232.0             4495.29
# 10299        4.59        0.15               821.0             6695.90
# 10302        1.92        0.03              6368.0             2592.56
# 10303        9.60        0.32             26603.0            19194.37
# 10304        7.72        0.13              3772.0             3567.08
# 10305        7.72        0.13             39688.0            28277.42
# 10306        4.59        0.15              1504.0             1653.90
# 10310        3.60        0.06              2253.0             3785.72
# 10315       18.64        0.16             15198.0            26180.00
# 10316        6.52        0.11              1547.0             3410.00
#
#        line item insurance (usd)
# 19                        128.00
# 22                          3.07
# 23                         65.75
# 24                         86.39
# 25                         14.00
# 26                        320.00
# 27                        320.00
# 28                        320.00
# 29                        158.72
# 30                        432.00
# 32                         27.20
# 33                          5.36
# 34                          0.02
# 38                         57.88
# 39                         25.83
# 41                          0.00
# 43                        188.21
# 44                         61.56
# 45                         16.36
# 46                        154.29
# 49                          4.48
# 51                        703.66
# 54                         29.37
# 58                         98.35
# 59                         15.68
# 60                         22.88
# 62                        148.38
# 63                          2.48
# 64                         97.44
# 66                        335.54
# ...                          ...
# 10247                     383.09
# 10248                       0.72
# 10253                       8.11
# 10256                     103.69
# 10257                     717.06
# 10258                     252.16
# 10260                     253.16
# 10261                      99.42
# 10267                       6.07
# 10268                      40.39
# 10269                      52.72
# 10270                       1.55
# 10274                      33.28
# 10278                     270.71
# 10281                     375.31
# 10282                      87.61
# 10286                      19.17
# 10287                     554.84
# 10292                     129.12
# 10293                       0.84
# 10296                     251.60
# 10299                      44.57
# 10302                     107.87
# 10303                    2259.84
# 10304                     226.31
# 10305                    2725.93
# 10306                      75.52
# 10310                      76.27
# 10315                    1341.33
# 10316                     115.11
#
# [5856 rows x 15 columns]

# %%
#df_country = df['country']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5856 entries, 19 to 10316
# Data columns (total 15 columns):
# country                       5856 non-null object
# fulfill via                   5856 non-null object
# vendor inco term              5856 non-null object
# shipment mode                 5856 non-null object
# product group                 5856 non-null object
# sub classification            5856 non-null object
# brand                         5856 non-null object
# unit of measure (per pack)    5856 non-null int64
# line item quantity            5856 non-null int64
# line item value               5856 non-null float64
# pack price                    5856 non-null float64
# unit price                    5856 non-null float64
# weight (kilograms)            5856 non-null float64
# freight cost (usd)            5856 non-null float64
# line item insurance (usd)     5856 non-null float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 732.0+ KB

# %%
#df_country = pd.DataFrame(df['country'])

# %%
df.describe()
# Out:
#        unit of measure (per pack)  line item quantity  line item value  \
# count                 5856.000000         5856.000000     5.856000e+03
# mean                    75.955430        22055.165642     1.961590e+05
# std                     79.461844        43850.465668     3.801484e+05
# min                      1.000000            1.000000     0.000000e+00
# 25%                     30.000000         1000.000000     1.037017e+04
# 50%                     60.000000         4997.500000     5.995570e+04
# 75%                    100.000000        23040.000000     2.270781e+05
# max                   1000.000000       619999.000000     5.951990e+06
#
#         pack price   unit price  weight (kilograms)  freight cost (usd)  \
# count  5856.000000  5856.000000         5856.000000         5856.000000
# mean     23.879940     0.722176         3295.062329        11346.840558
# std      46.546248     2.751195         7094.982165        16045.083885
# min       0.000000     0.000000            0.000000            0.750000
# 25%       4.300000     0.090000          216.750000         2205.147500
# 50%       9.355000     0.160000         1098.000000         6037.085000
# 75%      27.000000     0.660000         3397.500000        14629.425000
# max    1250.000000    30.000000       154780.000000       289653.200000
#
#        line item insurance (usd)
# count                5856.000000
# mean                  297.841578
# std                   556.959841
# min                     0.000000
# 25%                    15.777500
# 50%                    90.560000
# 75%                   337.022500
# max                  7708.440000

# %%
df_raw['country'].value_counts().plot(kind='bar' )
plt.title('Destinations')
plt.xlabel('Countries')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
df_raw['unit of measure (per pack)'].value_counts().plot(kind='bar' )
plt.title('Units')
plt.xlabel('Volume (ml)')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
df_raw['shipment mode'].value_counts().plot(kind='bar')

# %%
df_raw['vendor inco term'].value_counts().plot(kind='bar')

# %%
df_raw['fulfill via'].value_counts().plot(kind='bar')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
corr = df.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
corr
# Out:
#                             unit of measure (per pack)  line item quantity  \
# unit of measure (per pack)                    1.000000           -0.149323
# line item quantity                           -0.149323            1.000000
# line item value                              -0.121997            0.818252
# pack price                                    0.120812           -0.161961
# unit price                                   -0.141700           -0.084316
# weight (kilograms)                           -0.077230            0.708330
# freight cost (usd)                           -0.054846            0.373443
# line item insurance (usd)                    -0.126294            0.777468
#
#                             line item value  pack price  unit price  \
# unit of measure (per pack)        -0.121997    0.120812   -0.141700
# line item quantity                 0.818252   -0.161961   -0.084316
# line item value                    1.000000   -0.019623   -0.034486
# pack price                        -0.019623    1.000000    0.239447
# unit price                        -0.034486    0.239447    1.000000
# weight (kilograms)                 0.690620   -0.115613   -0.035361
# freight cost (usd)                 0.429410   -0.006048    0.137345
# line item insurance (usd)          0.961317   -0.022548   -0.038223
#
#                             weight (kilograms)  freight cost (usd)  \
# unit of measure (per pack)           -0.077230           -0.054846
# line item quantity                    0.708330            0.373443
# line item value                       0.690620            0.429410
# pack price                           -0.115613           -0.006048
# unit price                           -0.035361            0.137345
# weight (kilograms)                    1.000000            0.464314
# freight cost (usd)                    0.464314            1.000000
# line item insurance (usd)             0.625407            0.379495
#
#                             line item insurance (usd)
# unit of measure (per pack)                  -0.126294
# line item quantity                           0.777468
# line item value                              0.961317
# pack price                                  -0.022548
# unit price                                  -0.038223
# weight (kilograms)                           0.625407
# freight cost (usd)                           0.379495
# line item insurance (usd)                    1.000000

# %%
plt.scatter(df['line item value'],df['line item insurance (usd)'])
plt.title("Value vs Insurance")
# Out:
# Text(0.5, 1.0, 'Value vs Insurance')

# %%
plt.scatter(df['pack price'],df['freight cost (usd)'])
plt.title("Pack Price vs Freight")
# Out:
# Text(0.5, 1.0, 'Pack Price vs Freight')

# %%
plt.scatter(df['line item quantity'],df['freight cost (usd)'])
plt.title("Quantity vs Freight")
# Out:
# Text(0.5, 1.0, 'Quantity vs Freight')

# %%
plt.scatter(df['line item value'],df['freight cost (usd)'])
plt.title("Value vs Freight")
# Out:
# Text(0.5, 1.0, 'Value vs Freight')

# %%
plt.scatter(df['line item insurance (usd)'],df['freight cost (usd)'])
plt.title("Insurance vs Freight")
# Out:
# Text(0.5, 1.0, 'Insurance vs Freight')

# %% [markdown]
# from sklearn.preprocessing import OneHotEncoder
# enc = OneHotEncoder(handle_unknown='ignore')
# X = np.array(df_country).reshape(-1,1)
# enc.fit(X)
# onehotlabels = enc.transform(X)
# onehotlabels.toarray()

# %% [markdown]
# country_list = df.country.unique()
# new_df = pd.DataFrame(data=onehotlabels,index = len(country_list) ,columns=country_list)
# country_list[32]

# %%
country = pd.get_dummies(df['country'],prefix=['country'])
fulfillment = pd.get_dummies(df['fulfill via'],prefix=['fulfill'])
incoterm = pd.get_dummies(df['vendor inco term'],prefix=['incoterm'])
shipment_mode = pd.get_dummies(df['shipment mode'],prefix=['mode'])
product = pd.get_dummies(df['product group'],prefix=['product'])
classification = pd.get_dummies(df['sub classification'],prefix=['class'])
brand = pd.get_dummies(df['brand'],prefix=['brand'])

# %%
df = df.drop(['country',
'fulfill via',
'vendor inco term',
'shipment mode',
'product group',
'sub classification',
'brand'],axis = 1)

# %%
df_final = df.join([country,fulfillment, incoterm,shipment_mode,product, classification,brand])
df_final.shape
# Out:
# (5856, 111)

# %%
df_final
# Out:
#        unit of measure (per pack)  line item quantity  line item value  \
# 19                            100                1000         80000.00
# 22                            240                1000          1920.00
# 23                            120                 500         41095.00
# 24                            100                 750         53992.50
# 25                            100                  25          8750.00
# 26                             25               10000        200000.00
# 27                             25               10000        200000.00
# 28                             25               10000        200000.00
# 29                             60               64000         99200.00
# 30                             20               10000        270000.00
# 32                             30                1000         17000.00
# 33                             60                 400          3352.00
# 34                            100                1500            15.00
# 38                             40                 476         36176.00
# 39                             25                 659         13180.00
# 41                            100                 213             2.13
# 43                            100                1634        117631.66
# 44                             20                1425         38475.00
# 45                            100                 142         10222.58
# 46                             30                8400         96432.00
# 49                             60                 400          2800.00
# 51                            100                5498        439785.02
# 54                             30                1344         18359.04
# 58                             30                2597         61470.99
# 59                            100                  28          9800.00
# 60                            100                  84         11676.00
# 62                             60               38640         92736.00
# 63                            540                  34          1547.68
# 64                             60               42000         60900.00
# 66                             30               16800        171192.00
# ...                           ...                 ...              ...
# 10247                          60               45950        372654.50
# 10248                          90                  75           697.50
# 10253                          60                1973          7892.00
# 10256                         120                5337        100869.30
# 10257                          60               86008        697524.88
# 10258                          60               65761        245288.53
# 10260                          60               66023        246265.79
# 10261                          60               14653         96709.80
# 10267                          90                 635          5905.50
# 10268                          30               12241         39293.61
# 10269                          30                3793         51281.36
# 10270                          60                 228          1504.80
# 10274                          30                2400         32376.00
# 10278                          30               57000        263340.00
# 10281                          60               55995        365087.40
# 10282                          30               18447         85225.14
# 10286                          60                5000         18650.00
# 10287                          30               55300        539728.00
# 10292                          30               27365        125605.35
# 10293                          30                 200           710.00
# 10296                         120               13130        244743.20
# 10299                          30                8250         37867.50
# 10302                          60               47733         91647.36
# 10303                          30              200000       1920000.00
# 10304                          60               28516        220143.52
# 10305                          60              300000       2316000.00
# 10306                          30               16006         73467.54
# 10310                          60               18000         64800.00
# 10315                         120               70000       1304800.00
# 10316                          60               15000         97800.00
#
#        pack price  unit price  weight (kilograms)  freight cost (usd)  \
# 19          80.00        0.80               341.0             2682.47
# 22           1.92        0.01               941.0             4193.49
# 23          82.19        0.68               117.0             1767.38
# 24          71.99        0.72               171.0             3518.38
# 25         350.00        3.50                60.0             3097.85
# 26          20.00        0.80              3335.0            27869.74
# 27          20.00        0.80              3335.0            28461.10
# 28          20.00        0.80              3335.0            28359.80
# 29           1.55        0.03              4228.0            12237.61
# 30          27.00        1.35              3263.0            20885.78
# 32          17.00        0.57                76.0             2282.57
# 33           8.38        0.14                23.0             2149.05
# 34           0.01        0.00                99.0                0.75
# 38          76.00        1.90               509.0             5446.51
# 39          20.00        0.80               206.0             2656.12
# 41           0.01        0.00                14.0              360.00
# 43          71.99        0.72               373.0             4112.46
# 44          27.00        1.35               483.0             5468.88
# 45          71.99        0.72                33.0             1715.17
# 46          11.48        0.38               654.0             4051.34
# 49           7.00        0.12                81.0             2211.05
# 51          79.99        0.80              1251.0            16090.22
# 54          13.66        0.46              1537.0            13507.92
# 58          23.67        0.79               117.0              645.10
# 59         350.00        3.50               109.0              782.13
# 60         139.00        1.39                54.0              871.57
# 62           2.40        0.04              2719.0            18614.72
# 63          45.52        0.08               115.0             1755.87
# 64           1.45        0.02              2600.0            10179.16
# 66          10.19        0.34              1224.0             4686.88
# ...           ...         ...                 ...                 ...
# 10247        8.11        0.14              6061.0             6901.96
# 10248        9.30        0.10                 5.0              908.65
# 10253        4.00        0.07              8894.0              102.67
# 10256       18.90        0.16              1089.0             3730.80
# 10257        8.11        0.14             11117.0            15617.93
# 10258        3.73        0.06              3156.0            28812.57
# 10260        3.73        0.06              5780.0            15789.20
# 10261        6.60        0.11              1413.0             1325.68
# 10267        9.30        0.10                65.0              177.00
# 10268        3.21        0.11               828.0             3773.00
# 10269       13.52        0.45               383.0              123.70
# 10270        6.60        0.11                21.0              973.48
# 10274       13.49        0.45               213.0             1422.54
# 10278        4.62        0.15              5735.0            20138.00
# 10281        6.52        0.11              4899.0            19497.24
# 10282        4.62        0.15              1906.0             2201.74
# 10286        3.73        0.06               297.0             1326.00
# 10287        9.76        0.33              6247.0            61201.46
# 10292        4.59        0.15              2885.0             2564.94
# 10293        3.55        0.12                12.0             1301.94
# 10296       18.64        0.16              3232.0             4495.29
# 10299        4.59        0.15               821.0             6695.90
# 10302        1.92        0.03              6368.0             2592.56
# 10303        9.60        0.32             26603.0            19194.37
# 10304        7.72        0.13              3772.0             3567.08
# 10305        7.72        0.13             39688.0            28277.42
# 10306        4.59        0.15              1504.0             1653.90
# 10310        3.60        0.06              2253.0             3785.72
# 10315       18.64        0.16             15198.0            26180.00
# 10316        6.52        0.11              1547.0             3410.00
#
#        line item insurance (usd)  ['country']_Afghanistan  ['country']_Angola  \
# 19                        128.00                        0                   0
# 22                          3.07                        0                   0
# 23                         65.75                        0                   0
# 24                         86.39                        0                   0
# 25                         14.00                        0                   0
# 26                        320.00                        0                   0
# 27                        320.00                        0                   0
# 28                        320.00                        0                   0
# 29                        158.72                        0                   0
# 30                        432.00                        0                   0
# 32                         27.20                        0                   0
# 33                          5.36                        0                   0
# 34                          0.02                        0                   0
# 38                         57.88                        0                   0
# 39                         25.83                        0                   0
# 41                          0.00                        0                   0
# 43                        188.21                        0                   0
# 44                         61.56                        0                   0
# 45                         16.36                        0                   0
# 46                        154.29                        0                   0
# 49                          4.48                        0                   0
# 51                        703.66                        0                   0
# 54                         29.37                        0                   0
# 58                         98.35                        0                   0
# 59                         15.68                        0                   0
# 60                         22.88                        0                   0
# 62                        148.38                        0                   0
# 63                          2.48                        0                   0
# 64                         97.44                        0                   0
# 66                        335.54                        0                   0
# ...                          ...                      ...                 ...
# 10247                     383.09                        0                   0
# 10248                       0.72                        0                   0
# 10253                       8.11                        0                   0
# 10256                     103.69                        0                   0
# 10257                     717.06                        0                   0
# 10258                     252.16                        0                   0
# 10260                     253.16                        0                   0
# 10261                      99.42                        0                   0
# 10267                       6.07                        0                   0
# 10268                      40.39                        0                   0
# 10269                      52.72                        0                   0
# 10270                       1.55                        0                   0
# 10274                      33.28                        0                   0
# 10278                     270.71                        0                   0
# 10281                     375.31                        0                   0
# 10282                      87.61                        0                   0
# 10286                      19.17                        0                   0
# 10287                     554.84                        0                   0
# 10292                     129.12                        0                   0
# 10293                       0.84                        0                   0
# 10296                     251.60                        0                   0
# 10299                      44.57                        0                   0
# 10302                     107.87                        0                   0
# 10303                    2259.84                        0                   0
# 10304                     226.31                        0                   0
# 10305                    2725.93                        0                   0
# 10306                      75.52                        0                   0
# 10310                      76.27                        0                   0
# 10315                    1341.33                        0                   0
# 10316                     115.11                        0                   0
#
#              ...         ['brand']_Stat-Pak  ['brand']_Stocrin/Sustiva  \
# 19           ...                          0                          0
# 22           ...                          0                          0
# 23           ...                          0                          0
# 24           ...                          0                          0
# 25           ...                          0                          0
# 26           ...                          0                          0
# 27           ...                          0                          0
# 28           ...                          0                          0
# 29           ...                          0                          0
# 30           ...                          1                          0
# 32           ...                          0                          0
# 33           ...                          0                          0
# 34           ...                          0                          0
# 38           ...                          0                          0
# 39           ...                          0                          0
# 41           ...                          0                          0
# 43           ...                          0                          0
# 44           ...                          1                          0
# 45           ...                          0                          0
# 46           ...                          0                          0
# 49           ...                          0                          0
# 51           ...                          0                          0
# 54           ...                          0                          0
# 58           ...                          0                          0
# 59           ...                          0                          0
# 60           ...                          0                          0
# 62           ...                          0                          0
# 63           ...                          0                          0
# 64           ...                          0                          0
# 66           ...                          0                          0
# ...          ...                        ...                        ...
# 10247        ...                          0                          0
# 10248        ...                          0                          0
# 10253        ...                          0                          0
# 10256        ...                          0                          0
# 10257        ...                          0                          0
# 10258        ...                          0                          0
# 10260        ...                          0                          0
# 10261        ...                          0                          0
# 10267        ...                          0                          0
# 10268        ...                          0                          0
# 10269        ...                          0                          0
# 10270        ...                          0                          0
# 10274        ...                          0                          0
# 10278        ...                          0                          0
# 10281        ...                          0                          0
# 10282        ...                          0                          0
# 10286        ...                          0                          0
# 10287        ...                          0                          0
# 10292        ...                          0                          0
# 10293        ...                          0                          0
# 10296        ...                          0                          0
# 10299        ...                          0                          0
# 10302        ...                          0                          0
# 10303        ...                          0                          0
# 10304        ...                          0                          0
# 10305        ...                          0                          0
# 10306        ...                          0                          0
# 10310        ...                          0                          0
# 10315        ...                          0                          0
# 10316        ...                          0                          0
#
#        ['brand']_Trizivir  ['brand']_Truvada  ['brand']_Uni-Gold  \
# 19                      0                  0                   0
# 22                      0                  0                   0
# 23                      0                  0                   0
# 24                      0                  0                   0
# 25                      0                  0                   0
# 26                      0                  0                   0
# 27                      0                  0                   0
# 28                      0                  0                   0
# 29                      0                  0                   0
# 30                      0                  0                   0
# 32                      0                  0                   0
# 33                      0                  0                   0
# 34                      0                  0                   0
# 38                      0                  0                   0
# 39                      0                  0                   0
# 41                      0                  0                   0
# 43                      0                  0                   0
# 44                      0                  0                   0
# 45                      0                  0                   0
# 46                      0                  0                   0
# 49                      0                  0                   0
# 51                      0                  0                   0
# 54                      0                  0                   0
# 58                      0                  0                   0
# 59                      0                  0                   0
# 60                      0                  0                   0
# 62                      0                  0                   0
# 63                      0                  0                   0
# 64                      0                  0                   0
# 66                      0                  0                   0
# ...                   ...                ...                 ...
# 10247                   0                  0                   0
# 10248                   0                  0                   0
# 10253                   0                  0                   0
# 10256                   0                  0                   0
# 10257                   0                  0                   0
# 10258                   0                  0                   0
# 10260                   0                  0                   0
# 10261                   0                  0                   0
# 10267                   0                  0                   0
# 10268                   0                  0                   0
# 10269                   0                  0                   0
# 10270                   0                  0                   0
# 10274                   0                  0                   0
# 10278                   0                  0                   0
# 10281                   0                  0                   0
# 10282                   0                  0                   0
# 10286                   0                  0                   0
# 10287                   0                  0                   0
# 10292                   0                  0                   0
# 10293                   0                  0                   0
# 10296                   0                  0                   0
# 10299                   0                  0                   0
# 10302                   0                  0                   0
# 10303                   0                  0                   0
# 10304                   0                  0                   0
# 10305                   0                  0                   0
# 10306                   0                  0                   0
# 10310                   0                  0                   0
# 10315                   0                  0                   0
# 10316                   0                  0                   0
#
#        ['brand']_Videx  ['brand']_Videx EC  ['brand']_Viracept  \
# 19                   0                   0                   0
# 22                   0                   0                   0
# 23                   0                   0                   0
# 24                   0                   0                   0
# 25                   0                   0                   0
# 26                   0                   0                   0
# 27                   0                   0                   0
# 28                   0                   0                   0
# 29                   0                   0                   0
# 30                   0                   0                   0
# 32                   0                   0                   0
# 33                   0                   0                   0
# 34                   0                   0                   0
# 38                   0                   0                   0
# 39                   0                   0                   0
# 41                   0                   0                   0
# 43                   0                   0                   0
# 44                   0                   0                   0
# 45                   0                   0                   0
# 46                   0                   0                   0
# 49                   1                   0                   0
# 51                   0                   0                   0
# 54                   0                   0                   0
# 58                   0                   1                   0
# 59                   0                   0                   0
# 60                   0                   0                   0
# 62                   0                   0                   0
# 63                   0                   0                   0
# 64                   0                   0                   0
# 66                   0                   0                   0
# ...                ...                 ...                 ...
# 10247                0                   0                   0
# 10248                0                   0                   0
# 10253                0                   0                   0
# 10256                0                   0                   0
# 10257                0                   0                   0
# 10258                0                   0                   0
# 10260                0                   0                   0
# 10261                0                   0                   0
# 10267                0                   0                   0
# 10268                0                   0                   0
# 10269                0                   0                   0
# 10270                0                   0                   0
# 10274                0                   0                   0
# 10278                0                   0                   0
# 10281                0                   0                   0
# 10282                0                   0                   0
# 10286                0                   0                   0
# 10287                0                   0                   0
# 10292                0                   0                   0
# 10293                0                   0                   0
# 10296                0                   0                   0
# 10299                0                   0                   0
# 10302                0                   0                   0
# 10303                0                   0                   0
# 10304                0                   0                   0
# 10305                0                   0                   0
# 10306                0                   0                   0
# 10310                0                   0                   0
# 10315                0                   0                   0
# 10316                0                   0                   0
#
#        ['brand']_Viread  ['brand']_Ziagen
# 19                    0                 0
# 22                    0                 0
# 23                    0                 0
# 24                    0                 0
# 25                    0                 0
# 26                    0                 0
# 27                    0                 0
# 28                    0                 0
# 29                    0                 0
# 30                    0                 0
# 32                    1                 0
# 33                    0                 0
# 34                    0                 0
# 38                    0                 0
# 39                    0                 0
# 41                    0                 0
# 43                    0                 0
# 44                    0                 0
# 45                    0                 0
# 46                    0                 0
# 49                    0                 0
# 51                    0                 0
# 54                    0                 0
# 58                    0                 0
# 59                    0                 0
# 60                    0                 0
# 62                    0                 0
# 63                    0                 0
# 64                    0                 0
# 66                    0                 0
# ...                 ...               ...
# 10247                 0                 0
# 10248                 0                 0
# 10253                 0                 0
# 10256                 0                 0
# 10257                 0                 0
# 10258                 0                 0
# 10260                 0                 0
# 10261                 0                 0
# 10267                 0                 0
# 10268                 0                 0
# 10269                 0                 0
# 10270                 0                 0
# 10274                 0                 0
# 10278                 0                 0
# 10281                 0                 0
# 10282                 0                 0
# 10286                 0                 0
# 10287                 0                 0
# 10292                 0                 0
# 10293                 0                 0
# 10296                 0                 0
# 10299                 0                 0
# 10302                 0                 0
# 10303                 0                 0
# 10304                 0                 0
# 10305                 0                 0
# 10306                 0                 0
# 10310                 0                 0
# 10315                 0                 0
# 10316                 0                 0
#
# [5856 rows x 111 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
labels = df_final['freight cost (usd)']
Train1 = df_final.drop(['freight cost (usd)'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(Train1, labels, test_size=0.1, random_state=2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.score(x_test,y_test)
# Out:
# 0.40401329569172517
